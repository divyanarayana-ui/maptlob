# %%
import matplotlib as mpl
import matplotlib.pyplot as plot 
import numpy as np
import pandas as pd

# %%
plot.plot(np.random.normal(size=200),np.random.normal(size=200),'o')

# %%
# %matplotlib inline

# %%
plot.plot(np.random.normal(size=200), np.random.normal(size=200),'d')

# %%
normals=pd.Series(np.random.normal(size=30))
print(normals)
normals.plot()
# Out:
# 0    -0.668441
# 1    -1.765391
# 2    -0.221762
# 3     0.779900
# 4    -0.321930
# 5     0.020723
# 6     1.551574
# 7    -1.125761
# 8     1.563678
# 9    -0.696964
# 10    2.002726
# 11    0.644012
# 12    2.318065
# 13    1.304268
# 14    0.791178
# 15   -0.166630
# 16   -0.859783
# 17   -0.221152
# 18    0.470105
# 19   -0.082399
# 20    0.057828
# 21    0.757678
# 22   -1.104000
# 23   -0.897895
# 24   -0.432653
# 25    0.706113
# 26   -0.126332
# 27    1.942927
# 28    0.383825
# 29   -0.504069
# dtype: float64

# %%
normals.cumsum().plot(grid=True)

# %%
variables=pd.DataFrame({'normal':np.random.normal(size=10),
                        'gamma':np.random.gamma(1, size=10),
                        'poisson':np.random.poisson(size=10)})
print(variables)
variables.cumsum(0).plot()
# Out:
#      normal     gamma  poisson
# 0 -0.351498  0.724691        1
# 1  0.195145  0.106430        1
# 2  0.504622  0.809800        2
# 3 -0.062879  0.172502        1
# 4 -0.565910  0.219761        1
# 5  2.206371  1.072641        2
# 6  1.444758  2.916277        1
# 7  1.481899  0.743070        0
# 8 -1.856930  1.243790        0
# 9  1.857566  0.608837        2

# %%
variables.cumsum(0).plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f55a7248ac8>,
# ...
#       dtype=object)

# %%
variables.cumsum(0).plot(secondary_y='normal')

# %%
fig, axes = plot.subplots(nrows=3, ncols=1, figsize=(4,12))
for i,var in enumerate(['normal','gamma','poisson']):
        variables[var].cumsum(0).plot(ax=axes[i],title=var)
        axes[0].set_ylabel('cumulative sum')

# %%
fig.savefig('figure.png')

# %%
# !ls -lh figure.png
# Out:
# -rw-r--r-- 1 root root 26K Sep 11 09:02 figure.png

# %%
from IPython.display import Image
Image('figure.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpeg': 'Joint Photographic Experts Group',
#  'jpg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig = plot.figure()
ax = plot.axes()

s = np.linspace(0, 20, 100)
print(s)
ax.plot(s, np.sin(s));
# Out:
# [ 0.          0.2020202   0.4040404   0.60606061  0.80808081  1.01010101
#   1.21212121  1.41414141  1.61616162  1.81818182  2.02020202  2.22222222
#   2.42424242  2.62626263  2.82828283  3.03030303  3.23232323  3.43434343
#   3.63636364  3.83838384  4.04040404  4.24242424  4.44444444  4.64646465
#   4.84848485  5.05050505  5.25252525  5.45454545  5.65656566  5.85858586
#   6.06060606  6.26262626  6.46464646  6.66666667  6.86868687  7.07070707
#   7.27272727  7.47474747  7.67676768  7.87878788  8.08080808  8.28282828
#   8.48484848  8.68686869  8.88888889  9.09090909  9.29292929  9.49494949
#   9.6969697   9.8989899  10.1010101  10.3030303  10.50505051 10.70707071
#  10.90909091 11.11111111 11.31313131 11.51515152 11.71717172 11.91919192
#  12.12121212 12.32323232 12.52525253 12.72727273 12.92929293 13.13131313
#  13.33333333 13.53535354 13.73737374 13.93939394 14.14141414 14.34343434
#  14.54545455 14.74747475 14.94949495 15.15151515 15.35353535 15.55555556
# ...

# %%
plot.plot(s,np.cos(s))

# %%
plot.plot(s,np.cos(s - 0), color='red')
plot.plot(s,np.cos(s - 1), color='y')
plot.plot(s,np.cos(s - 2), color='0.55')

# %%
plot.plot(s, np.cos(s - 0), linestyle='-')
plot.plot(s, np.cos(s - 1), linestyle=':')
plot.plot(s, np.cos(s - 2), linestyle='-.')

# %%
plot.plot(s, np.cos(s - 0))

plot.xlim(-1, 15)
plot.ylim(-2, 2);

# %%
plot.plot(s, np.cos(s))
plot.title("Cosine curve")
plot.xlabel("x")
plot.ylabel("cos(x)")
# Out:
# Text(0, 0.5, 'cos(x)')

# %%
plot.style.use('seaborn-whitegrid')

# %%
x= np.linspace(1, 10, 50)
y=np.log(x)

plot.plot(x, y, 'o-',color='green')

# %%
plot.plot(x, y,'-or');

# %%
plot.scatter(x, y,marker='o')

# %%
rng=np.random.RandomState(7)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.randn(100)
sizes=1000*rng.randn(100)

plot.scatter(x, y, c=colors, s=sizes, alpha=0.5,
             cmap='Reds')
plot.colorbar()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
x=np.linspace(0, 10, 100)
dy=0.1
y=np.cos(x) +dy*np.random.randn(100)
plot.errorbar(x, y,yerr=dy, fmt='.b');

# %%
plot.style.use('seaborn-white')
data=np.random.randn(10000)
print(data)
# Out:
# [ 2.35610991 -0.44359298 -0.09316886 ...  0.33751239  0.10435189
#  -0.46744002]

# %%
plot.hist(data)
# Out:
# (array([  22.,  193.,  856., 2054., 2872., 2489., 1166.,  300.,   43.,
#            5.]),
#  array([-3.5060125 , -2.75031559, -1.99461868, -1.23892177, -0.48322486,
#          0.27247204,  1.02816895,  1.78386586,  2.53956277,  3.29525968,
#          4.05095659]),
#  <a list of 10 Patch objects>)

# %%
plot.hist(data, bins=5, normed=True, alpha=0.6,
          histtype='stepfilled')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-53cdb63544be> in <module>()
#       1 plot.hist(data, bins=5, normed=True, alpha=0.6,
# ----> 2           histtype='stepfilled')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
x = np.random.normal(0, 0.8, 1000)
y = np.random.normal(-2, 1, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.5, normed=True, bins=50)

plot.hist(x, **kwargs)
plot.hist(y, **kwargs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-9ad58790bb07> in <module>()
#       4 kwargs = dict(histtype='stepfilled', alpha=0.5, normed=True, bins=50)
#       5
# ----> 6 plot.hist(x, **kwargs)
#       7 plot.hist(y, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %%
counts, bin_edges=np.histogram(data,bins=5)
print(counts)
# Out:
# [ 215 2910 5361 1466   48]

# %%
mean=[5,2]
cov=[[3,1],[2,0.5]]
x,y=np.random.multivariate_normal(mean,cov,10000)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: covariance is not positive-semidefinite.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-084227f265f8> in <module>()
#       1 mean=[5,2]
#       2 cov=[[3,1],[2,0.5]]
# ----> 3 x,y=np.random.multivariate_normal(mean,cov,10000)
#
# ValueError: too many values to unpack (expected 2)

# %%
plot.hist2d(x, y, bins=20,cmap='Reds')
cb=plot.colorbar()

# %%
plot.hexbin(x, y, gridsize=20, cmap='Reds')

cb=plot.colorbar
